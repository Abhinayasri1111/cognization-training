# %%
class bike:
    colour="black"
    speed=120
    brand="duke"
print(bike.colour)
print(bike.speed)
print(bike.brand)
# Out:
# black
# 120
# duke

# %%
class car:
    colour="white"
    speed=120
    brand="hero"
print(car.colour)
print(car.speed)
print(car.brand)
# Out:
# white
# 120
# hero
